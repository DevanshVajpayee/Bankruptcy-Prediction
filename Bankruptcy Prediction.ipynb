# %%
import pandas as pd
df = pd.read_csv('data.csv')
df.head()
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# ...

# %%
df.describe()
# Out:
#          Bankrupt?   ROA(C) before interest and depreciation before interest  \
# count  6819.000000                                        6819.000000
# mean      0.032263                                           0.505180
# std       0.176710                                           0.060686
# min       0.000000                                           0.000000
# 25%       0.000000                                           0.476527
# 50%       0.000000                                           0.502706
# 75%       0.000000                                           0.535563
# max       1.000000                                           1.000000
#
#         ROA(A) before interest and % after tax  \
# count                              6819.000000
# mean                                  0.558625
# std                                   0.065620
# min                                   0.000000
# 25%                                   0.535543
# ...

# %%
import numpy as np
import math
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %%
column_names = df.columns.tolist()

# print column names
print(column_names)
# Out:
# ['Bankrupt?', ' ROA(C) before interest and depreciation before interest', ' ROA(A) before interest and % after tax', ' ROA(B) before interest and depreciation after tax', ' Operating Gross Margin', ' Realized Sales Gross Margin', ' Operating Profit Rate', ' Pre-tax net Interest Rate', ' After-tax net Interest Rate', ' Non-industry income and expenditure/revenue', ' Continuous interest rate (after tax)', ' Operating Expense Rate', ' Research and development expense rate', ' Cash flow rate', ' Interest-bearing debt interest rate', ' Tax rate (A)', ' Net Value Per Share (B)', ' Net Value Per Share (A)', ' Net Value Per Share (C)', ' Persistent EPS in the Last Four Seasons', ' Cash Flow Per Share', ' Revenue Per Share (Yuan ¥)', ' Operating Profit Per Share (Yuan ¥)', ' Per Share Net profit before tax (Yuan ¥)', ' Realized Sales Gross Profit Growth Rate', ' Operating Profit Growth Rate', ' After-tax Net Profit Growth Rate', ' Regular Net Profit Growth Rate', ' Continuous Net Profit Growt
# ...

# %%
Y = df['Bankrupt?']
X = df.iloc[:,1:]
for col in range(95):
  X.iloc[:,col] = X.iloc[:,col]/(X.iloc[:,col].max())
X.head()
# Out:
# <ipython-input-9-66066e29fe45>:4: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   X.iloc[:,col] = X.iloc[:,col]/(X.iloc[:,col].max())
#     ROA(C) before interest and depreciation before interest  \
# 0                                           0.370594
# 1                                           0.464291
# 2                                           0.426071
# 3                                           0.399844
# 4                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state = 110, test_size=0.2)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
math.sqrt(len(Y_test))-1
# Out:
# 35.932370625238775

# %%
classifier = KNeighborsClassifier(n_neighbors=35,p=2, metric='euclidean')

# %%
nbrs = KNeighborsClassifier(n_neighbors=3).fit(X_train, Y_train)
nbrs.score(X_test,Y_test)
# Out:
# 0.9655425219941349

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (5455, 95)
# (1364, 95)

# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Load data
df = pd.read_csv('data.csv')

# Separate features and target variable
Y = df['Bankrupt?']
X = df.iloc[:,1:]

# Normalize features
scaler = MinMaxScaler()
X_norm = scaler.fit_transform(X)

# Train KNN classifier
classifier = KNeighborsClassifier(n_neighbors=35, p=2, metric='euclidean')
classifier.fit(X_norm, Y)

# Create example company data
example_company = np.array([0.729, 0.038, 0.995, 0.471, 0.521, 0.246, 0.587, 0.971, 0.416, 0.825, 0.024, 0.644, 0.076, 0.328, 0.968, 0.707, 0.961, 0.506, 0.556, 0.431, 0.516, 0.945, 0.217, 0.974, 0.148, 0.539, 0.475, 0.799, 0.182, 0.501, 0.072, 0.315, 0.191, 0.529, 0.401, 0.472, 0.086, 0.297, 0.594, 0.917, 0.447, 0.941, 0.705, 0.834, 0.335, 0.909, 0.426, 0.415, 0.678, 0.964, 0.734, 0.294, 0.027, 0.388, 0.131, 0.919, 0.308, 0.212, 0.183, 0.294, 0.557, 0.173, 0.418, 0.226, 0.967, 0.947, 0.134, 0.162, 0.338, 0.514, 0.947, 0.029, 0.681, 0.987, 0.375, 0.574, 0.768, 0.187, 0.042, 0.290, 0.834, 0.224, 0.512, 0.066, 0.644, 0.108, 0.598, 0.551, 0.083, 0.174, 0.401, 0.766, 0.706, 0.342, 0.586, 0.438, 0.424, 0.323, 0.861, 0.137, 0.862, 0.286, 0.350, 0.038])

# Normalize example company data
#example_norm = scaler.transform(example_company.reshape(1, -1))

# Predict bankruptcy status
prediction = classifier.predict(example)
print('Predicted bankruptcy type for example company is', prediction[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-ee58f29ccb1c> in <cell line: 29>()
#      27
#      28 # Predict bankruptcy status
# ---> 29 prediction = classifier.predict(example)
#      30 print('Predicted bankruptcy type for example company is', prediction[0])
#
# /usr/local/lib/python3.9/dist-packages/sklearn/neighbors/_classification.py in predict(self, X)
#     232             # In that case, we do not need the distances to perform
#     233             # the weighting so we do not compute them.
# --> 234             neigh_ind = self.kneighbors(X, return_distance=False)
#     235             neigh_dist = None
#     236         else:
#
# /usr/local/lib/python3.9/dist-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     804                 X = _check_precomputed(X)
#     805             else:
# ...

# %%
example_company = np.array([0.825, 0.024, 0.644, 0.076, 0.328, 0.968, 0.707, 0.961, 0.506, 0.556, 0.431, 0.516, 0.945, 0.217, 0.974, 0.148, 0.539, 0.475, 0.799, 0.182, 0.501, 0.072, 0.315, 0.191, 0.529, 0.401, 0.472, 0.086, 0.297, 0.594, 0.917, 0.447, 0.941, 0.705, 0.834, 0.335, 0.909, 0.426, 0.415, 0.678, 0.964, 0.734, 0.294, 0.027, 0.388, 0.131, 0.919, 0.308, 0.212, 0.183, 0.294, 0.557, 0.173, 0.418, 0.226, 0.967, 0.947, 0.134, 0.162, 0.338, 0.514, 0.947, 0.029, 0.681, 0.987, 0.375, 0.574, 0.768, 0.187, 0.042, 0.290, 0.834, 0.224, 0.512, 0.066, 0.644, 0.108, 0.598, 0.551, 0.083, 0.174, 0.401, 0.766, 0.706, 0.342, 0.586, 0.438, 0.424, 0.323, 0.861, 0.137, 0.862, 0.286, 0.350, 0.038])
example = example_company.reshape(1,-1)
x_scbcd = scaler.fit_transform(example)
print('Predicted bankrupt type for ', ' is ',
          Y[nbrs.predict(x_scbcd)[0]])
#print('Predicted bankrupt type for ', x_scbcd, ' is ',
 #         Y[nbrs.predict(example_company)[0]-1])
# Go to gold office hours
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cefc91b8c392> in <cell line: 1>()
# ----> 1 example_company = np.array([0.825, 0.024, 0.644, 0.076, 0.328, 0.968, 0.707, 0.961, 0.506, 0.556, 0.431, 0.516, 0.945, 0.217, 0.974, 0.148, 0.539, 0.475, 0.799, 0.182, 0.501, 0.072, 0.315, 0.191, 0.529, 0.401, 0.472, 0.086, 0.297, 0.594, 0.917, 0.447, 0.941, 0.705, 0.834, 0.335, 0.909, 0.426, 0.415, 0.678, 0.964, 0.734, 0.294, 0.027, 0.388, 0.131, 0.919, 0.308...
#       2 example = example_company.reshape(1,-1)
#       3 x_scbcd = scaler.fit_transform(example)
#       4 print('Predicted bankrupt type for ', ' is ',
#       5           Y[nbrs.predict(x_scbcd)[0]])
#
# NameError: name 'np' is not defined

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")
sns.countplot(x=df["Bankrupt?"])
# Out:
# <Axes: xlabel='Bankrupt?', ylabel='count'>

# %%
df.corr()
# Out:
#                                                     Bankrupt?  \
# Bankrupt?                                            1.000000
#  ROA(C) before interest and depreciation before...  -0.260807
#  ROA(A) before interest and % after tax             -0.282941
#  ROA(B) before interest and depreciation after tax  -0.273051
#  Operating Gross Margin                             -0.100043
# ...                                                       ...
#  Liability to Equity                                 0.166812
#  Degree of Financial Leverage (DFL)                  0.010508
#  Interest Coverage Ratio (Interest expense to E...  -0.005509
#  Net Income Flag                                          NaN
#  Equity to Liability                                -0.083048
#
#                                                      ROA(C) before interest and depreciation before interest  \
# Bankrupt?                                                                                   -0.260807
# ...

# %% [markdown]
# Repeat for more ratios

# %%
plt.figure(figsize=(5, 5))
sns.violinplot(data=df,
            x="Bankrupt?",
            y=" Current Liability to Assets",
            hue="Bankrupt?",
            dodge=True,
            width=0.5,
            palette = "bright",
       )

plt.title("Violin plot")
plt.show()

# %% [markdown]
# Create a new dataframe with only bankrupt to show different distribution

# %%
column_names = list(df.columns.values)
numbered_column_names = list(enumerate(column_names))
print(numbered_column_names)
# Out:
# [(0, 'Bankrupt?'), (1, ' ROA(C) before interest and depreciation before interest'), (2, ' ROA(A) before interest and % after tax'), (3, ' ROA(B) before interest and depreciation after tax'), (4, ' Operating Gross Margin'), (5, ' Realized Sales Gross Margin'), (6, ' Operating Profit Rate'), (7, ' Pre-tax net Interest Rate'), (8, ' After-tax net Interest Rate'), (9, ' Non-industry income and expenditure/revenue'), (10, ' Continuous interest rate (after tax)'), (11, ' Operating Expense Rate'), (12, ' Research and development expense rate'), (13, ' Cash flow rate'), (14, ' Interest-bearing debt interest rate'), (15, ' Tax rate (A)'), (16, ' Net Value Per Share (B)'), (17, ' Net Value Per Share (A)'), (18, ' Net Value Per Share (C)'), (19, ' Persistent EPS in the Last Four Seasons'), (20, ' Cash Flow Per Share'), (21, ' Revenue Per Share (Yuan ¥)'), (22, ' Operating Profit Per Share (Yuan ¥)'), (23, ' Per Share Net profit before tax (Yuan ¥)'), (24, ' Realized Sales Gross Profit Growth Ra
# ...

# %%
target = df['Bankrupt?'] >= 1
features = df.iloc[:,1:]
from sklearn.model_selection import train_test_split
f_train, f_test, t_train, t_test = train_test_split(features, target)
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(n_estimators=200)
forest.fit(f_train, t_train)
print(forest.score(f_test, t_test))
print(forest.feature_importances_)
# Out:
# 0.9747800586510263
# [1.09705530e-02 1.12294984e-02 1.02172532e-02 6.23825097e-03
#  7.27253243e-03 7.37472144e-03 1.07682660e-02 1.00852120e-02
#  1.66858682e-02 1.38184379e-02 1.00112738e-02 6.95965079e-03
#  5.87614434e-03 1.76960919e-02 1.75755583e-03 1.70795531e-02
#  1.62270375e-02 1.79371927e-02 2.24849522e-02 6.52795659e-03
#  8.36251278e-03 7.04708745e-03 1.38675985e-02 7.17526258e-03
#  7.83244538e-03 5.79555236e-03 5.74989098e-03 8.76113399e-03
#  8.09088076e-03 3.26096732e-02 1.03074644e-02 7.96026732e-03
#  9.17902887e-03 1.16188385e-02 1.83902981e-02 1.42847239e-02
#  1.64866075e-02 1.13406984e-02 6.80397876e-03 2.16030455e-02
#  5.02693193e-03 7.84006617e-03 1.61979288e-02 8.16672228e-03
#  7.52432676e-03 1.31763200e-02 8.73854775e-03 1.01824806e-02
#  1.05929143e-02 6.44051596e-03 9.62629935e-03 9.31513955e-03
#  9.37550922e-03 1.17894646e-02 6.54050289e-03 5.45955276e-03
#  1.77938396e-02 8.89688213e-03 1.39432511e-02 8.16084753e-03
# ...

# %%
example_company95 = np.array([0.825, 0.024, 0.644, 0.076, 0.328, 0.968, 0.707, 0.961, 0.506, 0.556, 0.431, 0.516, 0.945, 0.217, 0.974, 0.148, 0.539, 0.475, 0.799, 0.182, 0.501, 0.072, 0.315, 0.191, 0.529, 0.401, 0.472, 0.086, 0.297, 0.594, 0.917, 0.447, 0.941, 0.705, 0.834, 0.335, 0.909, 0.426, 0.415, 0.678, 0.964, 0.734, 0.294, 0.027, 0.388, 0.131, 0.919, 0.308, 0.212, 0.183, 0.294, 0.557, 0.173, 0.418, 0.226, 0.967, 0.947, 0.134, 0.162, 0.338, 0.514, 0.947, 0.029, 0.681, 0.987, 0.375, 0.574, 0.768, 0.187, 0.042, 0.290, 0.834, 0.224, 0.512, 0.066, 0.644, 0.108, 0.598, 0.551, 0.083, 0.174, 0.401, 0.766, 0.706, 0.342, 0.586, 0.438, 0.424, 0.323, 0.861, 0.137, 0.862, 0.286, 0.350, 0.038])
example_company104 = np.array([0.729, 0.038, 0.995, 0.471, 0.521, 0.246, 0.587, 0.971, 0.416, 0.825, 0.024, 0.644, 0.076, 0.328, 0.968, 0.707, 0.961, 0.506, 0.556, 0.431, 0.516, 0.945, 0.217, 0.974, 0.148, 0.539, 0.475, 0.799, 0.182, 0.501, 0.072, 0.315, 0.191, 0.529, 0.401, 0.472, 0.086, 0.297, 0.594, 0.917, 0.447, 0.941, 0.705, 0.834, 0.335, 0.909, 0.426, 0.415, 0.678, 0.964, 0.734, 0.294, 0.027, 0.388, 0.131, 0.919, 0.308, 0.212, 0.183, 0.294, 0.557, 0.173, 0.418, 0.226, 0.967, 0.947, 0.134, 0.162, 0.338, 0.514, 0.947, 0.029, 0.681, 0.987, 0.375, 0.574, 0.768, 0.187, 0.042, 0.290, 0.834, 0.224, 0.512, 0.066, 0.644, 0.108, 0.598, 0.551, 0.083, 0.174, 0.401, 0.766, 0.706, 0.342, 0.586, 0.438, 0.424, 0.323, 0.861, 0.137, 0.862, 0.286, 0.350, 0.038])
example = example_company95.reshape(1, -1)
predicted = forest.predict(example)
print("Predicted bankrupt status:", predicted[0])
# Out:
# Predicted bankrupt status: False
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
import numpy as np
print(np.where(forest.feature_importances_ == np.max(forest.feature_importances_))[0])
print(np.where(forest.feature_importances_ == np.min(forest.feature_importances_))[0])
# Out:
# [29]
# [93]

# %%
##30 most important
x=forest.feature_importances_
indices = x.argsort()[::-1]
highest_corr_features = f_train.columns[indices[:15]]
lowest_corr_features = f_train.columns[indices[-15:]]
print("Features with highest correlations with bankruptcy:")
print(highest_corr_features)
print("\nFeatures with lowest correlations with bankruptcy:")
print(lowest_corr_features)
# Out:
# Features with highest correlations with bankruptcy:
# Index([' Net Value Growth Rate', ' Net Income to Stockholder's Equity',
#        ' Persistent EPS in the Last Four Seasons', ' Borrowing dependency',
#        ' Interest Expense Ratio', ' Degree of Financial Leverage (DFL)',
#        ' Net Value Per Share (C)', ' Cash/Total Assets',
#        ' Interest-bearing debt interest rate',
#        ' Interest Coverage Ratio (Interest expense to EBIT)',
#        ' Net Value Per Share (B)',
#        ' Non-industry income and expenditure/revenue',
#        ' Working Capital/Equity', ' Debt ratio %', ' Net Value Per Share (A)'],
#       dtype='object')
#
# Features with lowest correlations with bankruptcy:
# Index([' Operating Funds to Liability', ' Net Worth Turnover Rate (times)',
#        ' Gross Profit to Sales', ' CFO to Assets', ' Operating Gross Margin',
#        ' Current Liabilities/Liability', ' Cash flow rate',
#        ' Long-term Liability to Current Assets',
# ...

# %%
plt.figure(figsize=(5, 5))
sns.violinplot(data=df,
            x="Bankrupt?",
            y=" Total Asset Growth Rate",
            hue="Bankrupt?",
            dodge=True,
            width=0.5,
            palette = "bright",
       )

plt.title("Violin plot")
plt.show()

# %%
corr_matrix = df.corr()
top3_corr = corr_matrix['Bankrupt?'].nlargest(4)[1:]
top3_corr
# Out:
#  Debt ratio %                   0.250161
#  Current Liability to Assets    0.194494
#  Borrowing dependency           0.176543
# Name: Bankrupt?, dtype: float64

# %%
less3_corr = corr_matrix['Bankrupt?'].nsmallest(4)[1:]
less3_corr
# Out:
#  ROA(A) before interest and % after tax                    -0.282941
#  ROA(B) before interest and depreciation after tax         -0.273051
#  ROA(C) before interest and depreciation before interest   -0.260807
# Name: Bankrupt?, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")
print(sns.barplot(x=df["Bankrupt?"], y=df[' Quick Asset Turnover Rate']))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
print(sns.barplot(x=df["Bankrupt?"], y=df[' Cash Flow to Total Assets']))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
print(sns.barplot(x=df["Bankrupt?"], y=df[' Cash flow rate']))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# LOGISTIC REGRESSION

# %%
#check for null values
df.isna().sum()
# Out:
# Bankrupt?                                                   0
#  ROA(C) before interest and depreciation before interest    0
#  ROA(A) before interest and % after tax                     0
#  ROA(B) before interest and depreciation after tax          0
#  Operating Gross Margin                                     0
#                                                            ..
#  Liability to Equity                                        0
#  Degree of Financial Leverage (DFL)                         0
#  Interest Coverage Ratio (Interest expense to EBIT)         0
#  Net Income Flag                                            0
#  Equity to Liability                                        0
# Length: 96, dtype: int64

# %%
import seaborn as sns
sns.heatmap(df.isna())
# Out:
# <Axes: >

# %%
df2= df[['Bankrupt?',' Net Value Growth Rate', ' Net Income to Stockholder\'s Equity',
       ' Persistent EPS in the Last Four Seasons', ' Borrowing dependency',
       ' Interest Expense Ratio', ' Degree of Financial Leverage (DFL)',
       ' Net Value Per Share (C)', ' Cash/Total Assets',
       ' Interest-bearing debt interest rate',
       ' Interest Coverage Ratio (Interest expense to EBIT)',
       ' Net Value Per Share (B)',
       ' Non-industry income and expenditure/revenue',
       ' Working Capital/Equity', ' Debt ratio %', ' Net Value Per Share (A)',' Operating Funds to Liability', ' Net Worth Turnover Rate (times)',
       ' Gross Profit to Sales', ' CFO to Assets', ' Operating Gross Margin',
       ' Current Liabilities/Liability', ' Cash flow rate',
       ' Long-term Liability to Current Assets',
       ' After-tax Net Profit Growth Rate', ' Regular Net Profit Growth Rate',
       ' Current Assets/Total Assets', ' Contingent liabilities/Net worth',
       ' Tax rate (A)', ' Liability-Assets Flag', ' Net Income Flag']]

# %%
df2.head()
# Out:
#    Bankrupt?   Net Value Growth Rate   Net Income to Stockholder's Equity  \
# 0          1                0.000327                             0.827890
# 1          1                0.000443                             0.839969
# 2          1                0.000396                             0.836774
# 3          1                0.000382                             0.834697
# 4          1                0.000439                             0.839973
#
#     Persistent EPS in the Last Four Seasons   Borrowing dependency  \
# 0                                  0.169141               0.390284
# 1                                  0.208944               0.376760
# 2                                  0.180581               0.379093
# 3                                  0.193722               0.379743
# 4                                  0.212537               0.375025
#
#     Interest Expense Ratio   Degree of Financial Leverage (DFL)  \
# ...

# %%
y = df2['Bankrupt?']
x = df2.iloc[:,1:]

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
import numpy as np
import matplotlib.pyplot as plt
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=110)

# %%
x_train.shape
# Out:
# (5455, 95)

# %%
x_test.shape
# Out:
# (1364, 95)

# %%
y_test.shape
# Out:
# (1364,)

# %%
y_train.shape
# Out:
# (5455,)

# %%
from sklearn.linear_model import LogisticRegression
Lr = LogisticRegression()
Lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
pr = Lr.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
pd.DataFrame(confusion_matrix(y_test, pr),columns = ['Predict No','Predict Yes'], index = ['Actual No','Actual Yes'])
# Out:
#             Predict No  Predict Yes
# Actual No         1306           15
# Actual Yes          43            0

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1321
#            1       0.00      0.00      0.00        43
#
#     accuracy                           0.96      1364
#    macro avg       0.48      0.49      0.49      1364
# weighted avg       0.94      0.96      0.95      1364

# %%
google = [[0.1,0.39,0,0.237757,0.880985,0.101208,0.016469,0.688979,0.247535,0.169141,0.390284,0.000327,0.137757,0.780985,0.001208,0.016469,0.688979,0.317535,0.095885,0.398036,0.00086957,0.688979,0.538736,0.122102,0.003487,0.424389,0.405750,0.601457,0.5,0.27]]
probabilities = Lr.predict_proba(google)[0][1]
print('Probability of bankruptcy: ', probabilities)
# Out:
# Probability of bankruptcy:  0.4999999990007381
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
